# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('../leaf/leaf.csv', sep = ',', engine = 'python')

# %%
data
# Out:
#      Class (Species)  Specimen Number  Eccentricity  Aspect Ratio  Elongation  \
# 0                  1                1       0.72694        1.4742     0.32396
# 1                  1                2       0.74173        1.5257     0.36116
# 2                  1                3       0.76722        1.5725     0.38998
# 3                  1                4       0.73797        1.4597     0.35376
# 4                  1                5       0.82301        1.7707     0.44462
# 5                  1                6       0.72997        1.4892     0.34284
# 6                  1                7       0.82063        1.7529     0.44458
# 7                  1                8       0.77982        1.6215     0.39222
# 8                  1                9       0.83089        1.8199     0.45693
# 9                  1               10       0.90631        2.3906     0.58336
# 10                 1               11       0.74590        1.4927     0.34116
# 11                 1               12       0.79606        1.6934     0.43387
# 12                 2                1       0.93361        2.7582     0.64257
# 13                 2                2       0.91186        2.4994     0.60323
# 14                 2                3       0.89063        2.2927     0.56667
# 15                 2                4       0.86755        2.0090     0.51464
# 16                 2                5       0.91852        2.5247     0.61648
# 17                 2                6       0.88795        2.2038     0.56218
# 18                 2                7       0.85121        1.9548     0.48920
# 19                 2                8       0.89084        2.2979     0.57815
# 20                 2                9       0.93062        2.8973     0.65828
# 21                 2               10       0.84113        1.8600     0.46549
# 22                 3                1       0.70273        1.2099     0.36317
# 23                 3                2       0.66307        1.2065     0.32559
# 24                 3                3       0.61289        1.0991     0.33117
# 25                 3                4       0.70668        1.2510     0.38111
# 26                 3                5       0.66889        1.1435     0.38460
# 27                 3                6       0.50139        1.0066     0.29593
# 28                 3                7       0.60803        1.0646     0.34460
# 29                 3                8       0.56599        1.0427     0.35318
# ..               ...              ...           ...           ...         ...
# 310               34                3       0.99670       11.3610     0.91400
# 311               34                4       0.99841       16.8320     0.94116
# 312               34                5       0.99799       15.0680     0.93667
# 313               34                6       0.99512       10.3770     0.90564
# 314               34                7       0.99505       10.7360     0.90851
# 315               34                8       0.99518       10.4210     0.90385
# 316               34                9       0.99530       10.6300     0.90598
# 317               34               10       0.99515       10.0070     0.90328
# 318               34               11       0.99871       19.0380     0.94834
# 319               35                1       0.91090        2.5488     0.61060
# 320               35                2       0.90391        2.4580     0.59770
# 321               35                3       0.90755        2.5820     0.62394
# 322               35                4       0.91708        2.6498     0.62919
# 323               35                5       0.91660        2.6711     0.63330
# 324               35                6       0.89420        2.4203     0.59323
# 325               35                7       0.93847        3.0198     0.67312
# 326               35                8       0.89518        2.3875     0.58100
# 327               35                9       0.91707        2.6504     0.63359
# 328               35               10       0.92535        2.8030     0.65133
# 329               35               11       0.91861        2.8114     0.64707
# 330               36                1       0.39093        1.1025     0.73351
# 331               36                2       0.47124        1.1349     0.81159
# 332               36                3       0.36870        1.0456     0.77124
# 333               36                4       0.14986        1.0558     0.77733
# 334               36                5       0.68069        1.1866     0.78745
# 335               36                6       0.37522        1.1417     0.81725
# 336               36                7       0.28064        1.0849     0.75319
# 337               36                8       0.35344        1.0329     0.78147
# 338               36                9       0.59988        1.1427     0.71532
# 339               36               10       0.47195        1.0901     0.85409
#
#      Solidity  Stochastic Convexity  Isoperimetric Factor  \
# 25%                     0.009521    0.016500           0.022843
# 50%                     0.023860    0.103615           0.042087
# 75%                     0.047834    0.416433           0.073046
# max                     0.198980    7.206200           0.190670
#
#        Average Contrast  Smoothness  Third moment  Uniformity     Entropy
# count        340.000000  340.000000    340.000000  340.000000  340.000000
# mean           0.124535    0.017670      0.005928    0.000387    1.162630
# std            0.051860    0.013755      0.005294    0.000431    0.584854
# min            0.033415    0.001115      0.000229    0.000007    0.169400
# 25%            0.083362    0.006901      0.002080    0.000102    0.718900
# 50%            0.119375    0.014050      0.004447    0.000239    1.077450
# 75%            0.163795    0.026127      0.008307    0.000516    1.554575
# max            0.280810    0.073089      0.029786    0.002936    2.708500

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(data[['Specimen Number', 'Eccentricity', 'Aspect Ratio', 'Elongation', 'Solidity']], figsize = (10, 10))
pass

# %%
data.corr()
# Out:
#                            Class (Species)  Specimen Number  Eccentricity  \
# Class (Species)                   1.000000        -0.015142      0.091415
# Specimen Number                  -0.015142         1.000000     -0.076772
# Eccentricity                      0.091415        -0.076772      1.000000
# Aspect Ratio                      0.275210        -0.025490      0.551069
# Elongation                        0.141275        -0.027722      0.553561
# Solidity                          0.111843        -0.071623      0.373536
# Stochastic Convexity              0.046678        -0.025219      0.386332
# Isoperimetric Factor             -0.049767         0.004129     -0.036086
# Maximal Indentation Depth        -0.040026         0.065016     -0.274361
# Lobedness                        -0.017048         0.062324     -0.213635
# Average Intensity                 0.102453        -0.009725     -0.226307
# Average Contrast                  0.076246        -0.012664     -0.194736
# Smoothness                        0.094885         0.004628     -0.191061
# Third moment                      0.058520         0.010632     -0.149555
# Uniformity                        0.187717        -0.040407     -0.250345
# Entropy                           0.017690        -0.033548     -0.239689
#
#                            Aspect Ratio  Elongation  Solidity  \
# Class (Species)                0.275210    0.141275  0.111843
# Specimen Number               -0.025490   -0.027722 -0.071623
# Eccentricity                   0.551069    0.553561  0.373536
# Aspect Ratio                   1.000000    0.678304  0.005173
# Elongation                     0.678304    1.000000 -0.411437
# Solidity                       0.005173   -0.411437  1.000000
# Stochastic Convexity           0.107148   -0.378827  0.862526
# Isoperimetric Factor          -0.471024   -0.793095  0.755480
# Maximal Indentation Depth      0.091851    0.437071 -0.885721
# Lobedness                      0.122447    0.407873 -0.823757
# Average Intensity             -0.282176   -0.204517  0.084869
# Average Contrast              -0.297516   -0.188545  0.082696
# Smoothness                    -0.263273   -0.178534  0.077565
# Third moment                  -0.233767   -0.151095  0.058905
# Uniformity                    -0.229363   -0.250682  0.126263
# Entropy                       -0.312881   -0.210903  0.055589
#
#                            Stochastic Convexity  Isoperimetric Factor  \
# Class (Species)                        0.046678             -0.049767
# Specimen Number                       -0.025219              0.004129
# Eccentricity                           0.386332             -0.036086
# Aspect Ratio                           0.107148             -0.471024
# Elongation                            -0.378827             -0.793095
# Solidity                               0.862526              0.755480
# Stochastic Convexity                   1.000000              0.655910
# Isoperimetric Factor                   0.655910              1.000000
# Maximal Indentation Depth             -0.769124             -0.735776
# Lobedness                             -0.699630             -0.624161
# Average Intensity                      0.063159              0.080628
# Average Contrast                       0.057957              0.078250
# Smoothness                             0.050713              0.074597
# Third moment                           0.036619              0.066503
# Uniformity                             0.106687              0.133144
# Entropy                                0.052572              0.069783
#
#                            Maximal Indentation Depth  Lobedness  \
# Class (Species)                            -0.040026  -0.017048
# Specimen Number                             0.065016   0.062324
# Eccentricity                               -0.274361  -0.213635
# Aspect Ratio                                0.091851   0.122447
# Elongation                                  0.437071   0.407873
# Solidity                                   -0.885721  -0.823757
# Stochastic Convexity                       -0.769124  -0.699630
# Isoperimetric Factor                       -0.735776  -0.624161
# Maximal Indentation Depth                   1.000000   0.946455
# Lobedness                                   0.946455   1.000000
# Average Intensity                          -0.090496  -0.169071
# Average Contrast                           -0.088703  -0.177816
# Smoothness                                 -0.058970  -0.149011
# Third moment                               -0.023151  -0.119249
# Uniformity                                 -0.137758  -0.169245
# Entropy                                    -0.111749  -0.181064
#
#                            Average Intensity  Average Contrast  Smoothness  \
# Class (Species)                     0.102453          0.076246    0.094885
# Specimen Number                    -0.009725         -0.012664    0.004628
# Eccentricity                       -0.226307         -0.194736   -0.191061
# Aspect Ratio                       -0.282176         -0.297516   -0.263273
# Elongation                         -0.204517         -0.188545   -0.178534
# Solidity                            0.084869          0.082696    0.077565
# Stochastic Convexity                0.063159          0.057957    0.050713
# Isoperimetric Factor                0.080628          0.078250    0.074597
# Maximal Indentation Depth          -0.090496         -0.088703   -0.058970
# Lobedness                          -0.169071         -0.177816   -0.149011
# Average Intensity                   1.000000          0.954795    0.955397
# Average Contrast                    0.954795          1.000000    0.979564
# Smoothness                          0.955397          0.979564    1.000000
# Third moment                        0.821688          0.917906    0.951044
# Uniformity                          0.804478          0.652714    0.639154
# Entropy                             0.935708          0.860100    0.820406
#
#                            Third moment  Uniformity   Entropy
# Class (Species)                0.058520    0.187717  0.017690
# Specimen Number                0.010632   -0.040407 -0.033548
# Eccentricity                  -0.149555   -0.250345 -0.239689
# Aspect Ratio                  -0.233767   -0.229363 -0.312881
# Elongation                    -0.151095   -0.250682 -0.210903
# Solidity                       0.058905    0.126263  0.055589
# Stochastic Convexity           0.036619    0.106687  0.052572
# Isoperimetric Factor           0.066503    0.133144  0.069783
# Maximal Indentation Depth     -0.023151   -0.137758 -0.111749
# Lobedness                     -0.119249   -0.169245 -0.181064
# Average Intensity              0.821688    0.804478  0.935708
# Average Contrast               0.917906    0.652714  0.860100
# Smoothness                     0.951044    0.639154  0.820406
# Third moment                   1.000000    0.409274  0.644978
# Uniformity                     0.409274    1.000000  0.797800
# Entropy                        0.644978    0.797800  1.000000

# %%
plt.plot(data['Solidity'], data['Elongation'], 'o', alpha = 0.5)
plt.xlabel('Solidity')
plt.ylabel('Elongation')
plt.title('Solidity vs Elongation')
pass

# %%
data['Stochastic Convexity'] == 1.00000
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4       True
# 5       True
# 6      False
# 7      False
# 8       True
# 9      False
# 10      True
# 11      True
# 12      True
# 13      True
# 14      True
# 15      True
# 16      True
# 17     False
# 18      True
# 19      True
# 20      True
# 21      True
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 310    False
# 311    False
# 312    False
# 313    False
# 314    False
# 315    False
# 316    False
# 317    False
# 318    False
# 319    False
# 320     True
# 321    False
# 322     True
# 323     True
# 324     True
# 325     True
# 326     True
# 327    False
# 328     True
# 329    False
# 330    False
# 331    False
# 332    False
# 333    False
# 334    False
# 335    False
# 336    False
# 337    False
# 338    False
# 339    False
# Name: Stochastic Convexity, Length: 340, dtype: bool

# %%
plt.figure(figsize = (10, 6))

plt.scatter(data[data['Entropy'] >=1]['Average Intensity'],
            data[data['Entropy'] >=1]['Average Contrast'],
            alpha = 0.15,
            label = '>=1',
            color = 'g')

plt.scatter(data[data['Entropy'] < 1]['Average Intensity'],
            data[data['Entropy'] < 1]['Average Contrast'],
            alpha = 0.05,
            label = '< 1',
            color = 'y')

plt.xlabel('Average Intensity')
plt.xticks((0.05, 0.1, 0.15))
plt.xlim(0, 0.2)
plt.ylabel('Average Contrast')
plt.legend()
plt.grid()

# %%
np.median(data['Entropy'])
# Out:
# 1.0774499999999998

# %%
data.describe(include = 'all')
# Out:
#        Class (Species)  Specimen Number  Eccentricity  Aspect Ratio  \
# count       340.000000       340.000000    340.000000    340.000000
# mean         18.544118         6.282353      0.719854      2.440210
# std          11.152514         3.462779      0.208311      2.599043
# min           1.000000         1.000000      0.117080      1.006600
# 25%           9.000000         3.000000      0.550622      1.211300
# 50%          15.000000         6.000000      0.763450      1.570750
# 75%          29.000000         9.000000      0.895097      2.343100
# max          36.000000        16.000000      0.998710     19.038000
#
#        Elongation    Solidity  Stochastic Convexity  Isoperimetric Factor  \
# count  340.000000  340.000000            340.000000            340.000000
# mean     0.513760    0.904158              0.943793              0.531234
# std      0.195583    0.114639              0.115047              0.217532
# min      0.107610    0.485490              0.396490              0.078376
# 25%      0.349623    0.890667              0.966230              0.346818
# 50%      0.501855    0.948130              0.992980              0.579160
# 75%      0.633373    0.976897              1.000000              0.700712
# max      0.948340    0.993880              1.000000              0.858160
#
#        Maximal Indentation Depth   Lobedness  Average Intensity  \
# count                 340.000000  340.000000         340.000000
# mean                    0.037345    0.523845           0.051346
# std                     0.038575    1.039639           0.035965
# min                     0.002837    0.001464           0.005022
# 25%                     0.009521    0.016500           0.022843
# 50%                     0.023860    0.103615           0.042087
# 75%                     0.047834    0.416433           0.073046
# max                     0.198980    7.206200           0.190670
#
#        Average Contrast  Smoothness  Third moment  Uniformity     Entropy
# count        340.000000  340.000000    340.000000  340.000000  340.000000
# mean           0.124535    0.017670      0.005928    0.000387    1.162630
# std            0.051860    0.013755      0.005294    0.000431    0.584854
# min            0.033415    0.001115      0.000229    0.000007    0.169400
# 25%            0.083362    0.006901      0.002080    0.000102    0.718900
# 50%            0.119375    0.014050      0.004447    0.000239    1.077450
# 75%            0.163795    0.026127      0.008307    0.000516    1.554575
# max            0.280810    0.073089      0.029786    0.002936    2.708500

# %%
data['Stochastic Convexity'].unique()
# Out:
# array([1.     , 0.99825, 0.99649, 0.98772, 0.98421, 0.99298, 0.97895,
#        0.99474, 0.83684, 0.91754, 0.85439, 0.86491, 0.89474, 0.85263,
#        0.83509, 0.90526, 0.87368, 0.89298, 0.85614, 0.87544, 0.47544,
#        0.59649, 0.56667, 0.84211, 0.56491, 0.62105, 0.66667, 0.8193 ,
#        0.97018, 0.95088, 0.96667, 0.97544, 0.97719, 0.96842, 0.89649,
#        0.97368, 0.96316, 0.97193, 0.96491, 0.9807 , 0.99123, 0.59298,
#        0.6    , 0.54211, 0.59123, 0.77368, 0.79474, 0.6614 , 0.68421,
#        0.75263, 0.49649, 0.62982, 0.68772, 0.64912, 0.63684, 0.53684,
#        0.81053, 0.98246, 0.87018, 0.93333, 0.9    , 0.90175, 0.94386,
#        0.77544, 0.90702, 0.84737, 0.98947, 0.98596, 0.94737, 0.9614 ,
#        0.85088, 0.92456, 0.86667, 0.92105, 0.95263, 0.86842, 0.89123,
#        0.95614, 0.93684, 0.93509, 0.95789, 0.69474, 0.47368, 0.66316,
#        0.58772, 0.71404, 0.61579, 0.39649])

# %%
data['Stochastic Convexity'].dtype.name
# Out:
# 'float64'

# %%
categorical_columns = [c for c in data.columns if data[c].dtype.name == 'object']
numerical_columns   = [c for c in data.columns if data[c].dtype.name != 'object']
print(categorical_columns)
print(numerical_columns)
# Out:
# []
# ['Class (Species)', 'Specimen Number', 'Eccentricity', 'Aspect Ratio', 'Elongation', 'Solidity', 'Stochastic Convexity', 'Isoperimetric Factor', 'Maximal Indentation Depth', 'Lobedness', 'Average Intensity', 'Average Contrast', 'Smoothness', 'Third moment', 'Uniformity', 'Entropy']

# %%
data.median(axis = 0)
# Out:
# Class (Species)              15.000000
# Specimen Number               6.000000
# Eccentricity                  0.763450
# Aspect Ratio                  1.570750
# Elongation                    0.501855
# Solidity                      0.948130
# Stochastic Convexity          0.992980
# Isoperimetric Factor          0.579160
# Maximal Indentation Depth     0.023860
# Lobedness                     0.103615
# Average Intensity             0.042087
# Average Contrast              0.119375
# Smoothness                    0.014050
# Third moment                  0.004447
# Uniformity                    0.000239
# Entropy                       1.077450
# dtype: float64

# %%
data = data.fillna(data.median(axis = 0), axis = 0)

# %%
binary_columns    = [c for c in categorical_columns if data_describe[c]['unique'] == 2]
nonbinary_columns = [c for c in categorical_columns if data_describe[c]['unique'] > 2]
print(binary_columns, nonbinary_columns)
# Out:
# [] []

# %%
data_numerical = data[numerical_columns]
data_numerical.describe()
# Out:
#        Class (Species)  Specimen Number  Eccentricity  Aspect Ratio  \
# count       340.000000       340.000000    340.000000    340.000000
# mean         18.544118         6.282353      0.719854      2.440210
# std          11.152514         3.462779      0.208311      2.599043
# min           1.000000         1.000000      0.117080      1.006600
# 25%           9.000000         3.000000      0.550622      1.211300
# 50%          15.000000         6.000000      0.763450      1.570750
# 75%          29.000000         9.000000      0.895097      2.343100
# max          36.000000        16.000000      0.998710     19.038000
#
#        Elongation    Solidity  Stochastic Convexity  Isoperimetric Factor  \
# count  340.000000  340.000000            340.000000            340.000000
# mean     0.513760    0.904158              0.943793              0.531234
# std      0.195583    0.114639              0.115047              0.217532
# min      0.107610    0.485490              0.396490              0.078376
# 25%      0.349623    0.890667              0.966230              0.346818
# 50%      0.501855    0.948130              0.992980              0.579160
# 75%      0.633373    0.976897              1.000000              0.700712
# max      0.948340    0.993880              1.000000              0.858160
#
#             Entropy
# count  3.400000e+02
# mean  -1.320839e-15
# std    1.000000e+00
# min   -1.698253e+00
# 25%   -7.587023e-01
# 50%   -1.456430e-01
# 75%    6.701592e-01
# max    2.643174e+00

# %%
X = data.drop(('Class (Species)'), axis = 1)
y = data['Class (Species)']
feature_names = X.columns

# %%
type(feature_names)
# Out:
# pandas.core.indexes.base.Index

# %%
print(X.shape)
print(y.shape)
N, d = X.shape
# Out:
# (340, 15)
# (340,)

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

N_train, _ = X_train.shape 
N_test,  _ = X_test.shape 

print(N_train, N_test)
# Out:
# 238 102

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors = 10)
#knn.set_params(n_neighbors=10)
knn.fit(X_train, y_train.astype("int"))
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=10, p=2,
#                      weights='uniform')

# %%
y_train_predict = knn.predict(X_train)
y_test_predict = knn.predict(X_test)

err_train = np.mean(y_train.astype("int") != y_train_predict)
err_test  = np.mean(y_test.astype("int")  != y_test_predict)

print(err_train, err_test)
# Out:
# 0.22268907563025211 0.27450980392156865

# %%
err_test = 1 - knn.score(X_test, y_test.astype("int"))

# %%
err_test
# Out:
# 0.27450980392156865

# %%
from sklearn.metrics import confusion_matrix

print(confusion_matrix(y_test.astype("int"), y_test_predict))
# Out:
# [[13  7  0]
#  [ 6 48  2]
#  [ 1 12 13]]

# %%
confusion_matrix([0,1,0,1,0], [0,1,0,0,0])
# Out:
# array([[3, 0],
#        [1, 1]], dtype=int64)

# %%
from sklearn.model_selection import GridSearchCV
nnb = [1, 3, 5, 10, 15, 20, 25, 35, 45, 55]
knn = KNeighborsClassifier()
grid = GridSearchCV(knn, param_grid = {'n_neighbors': nnb}, cv=10)
grid.fit(X_train, y_train.astype("int"))

best_cv_err = 1 - grid.best_score_
best_n_neighbors = grid.best_estimator_.n_neighbors
print(best_cv_err, best_n_neighbors)
# Out:
# 0.2226890756302521 1
# C:\Users\Maria\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)

# %%
knn = KNeighborsClassifier(n_neighbors = best_n_neighbors).fit(X_train, y_train.astype("int"))

err_train = np.mean(y_train.astype("int") != knn.predict(X_train))
err_test  = np.mean(y_test.astype("int")  != knn.predict(X_test))

print(err_train, err_test)
# Out:
# 0.0 0.23529411764705882

# %%
from sklearn.svm import SVC
svc = SVC()
svc.fit(X_train, y_train.astype("int"))

err_train = np.mean(y_train.astype("int") != svc.predict(X_train))
err_test  = np.mean(y_test.astype("int")  != svc.predict(X_test))

print(err_train, err_test)
# Out:
# 0.24789915966386555 0.29411764705882354
# C:\Users\Maria\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
from sklearn.model_selection import GridSearchCV
Cs = 10.**np.arange(-5, 5)
gamma_array = 10.**np.arange(-5, 5)
svc = SVC()
grid = GridSearchCV(svc, param_grid = {'C': Cs, 'gamma': gamma_array})
grid.fit(X_train, y_train.astype("int"))

best_cv_err = 1 - grid.best_score_
best_C = grid.best_estimator_.C
print(best_cv_err, best_C)
# Out:
# C:\Users\Maria\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# 0.18487394957983194 1000.0
# C:\Users\Maria\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)

# %%
svc = SVC(C = best_C).fit(X_train, y_train.astype("int"))

err_train = np.mean(y_train.astype("int") != knn.predict(X_train))
err_test  = np.mean(y_test.astype("int")  != knn.predict(X_test))

print(err_train, err_test)
# Out:
# 0.0 0.23529411764705882
# C:\Users\Maria\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
from sklearn import ensemble
rf = ensemble.RandomForestClassifier(n_estimators = 1000)
rf.fit(X_train, y_train.astype("int"))

err_train = np.mean(y_train.astype("int") != rf.predict(X_train))
err_test  = np.mean(y_test.astype("int")  != rf.predict(X_test))

print(err_train, err_test)
# Out:
# 0.0 0.21568627450980393

# %%
importances = rf.feature_importances_
indices = np.argsort(importances)[::-1]

print("Feature ranking:")

for f in range(d):
    print("%2d. feature '%5s' (%f)" % (f + 1, feature_names[indices[f]], importances[indices[f]]))
# Out:
# Feature ranking:
#  1. feature 'Solidity' (0.106471)
#  2. feature 'Elongation' (0.095944)
#  3. feature 'Isoperimetric Factor' (0.089282)
#  4. feature 'Aspect Ratio' (0.083757)
#  5. feature 'Eccentricity' (0.080123)
#  6. feature 'Uniformity' (0.079749)
#  7. feature 'Maximal Indentation Depth' (0.069864)
#  8. feature 'Lobedness' (0.066736)
#  9. feature 'Third moment' (0.056291)
# 10. feature 'Entropy' (0.055829)
# 11. feature 'Smoothness' (0.052596)
# 12. feature 'Average Contrast' (0.051777)
# 13. feature 'Average Intensity' (0.044198)
# 14. feature 'Stochastic Convexity' (0.040941)
# 15. feature 'Specimen Number' (0.026442)

# %%
np.sum(rf.feature_importances_)
# Out:
# 1.0

# %%
feature_names[[1,0,1]]
# Out:
# Index(['Eccentricity', 'Specimen Number', 'Eccentricity'], dtype='object')

# %%
d_first = 15
plt.title("Feature importances")
plt.bar(range(d_first), importances[indices[:d_first]], align = 'center', color = 'r')
plt.xticks(range(d_first), feature_names[indices[:d_first]], rotation = 90)
plt.xlim([-1, d_first])
# Out:
# (-1, 15)

# %%
ert = ensemble.ExtraTreesClassifier(n_estimators = 100).fit(X_train.astype("int"), y_train.astype("int"))

err_train = np.mean(y_train.astype("int") != ert.predict(X_train))
err_test  = np.mean(y_test.astype("int")  != ert.predict(X_test))

print(err_train, err_test)
# Out:
# 0.29831932773109243 0.37254901960784315

# %%
ada = ensemble.AdaBoostClassifier(n_estimators = 1000)
ada.fit(X_train.astype("int"), y_train.astype("int"))

err_train = np.mean(y_train.astype("int") != ada.predict(X_train))
err_test = np.mean(y_test.astype("int") != ada.predict(X_test))

print(err_train, err_test)
# Out:
# 0.42857142857142855 0.5

# %%
gbt = ensemble.GradientBoostingClassifier(n_estimators = 1000)
gbt.fit(X_train, y_train.astype("int"))

err_train = np.mean(y_train.astype("int") != gbt.predict(X_train))
err_test = np.mean(y_test.astype("int") != gbt.predict(X_test))

print(err_train, err_test)
# Out:
# 0.0 0.27450980392156865

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
X_train_PCA = pca.fit_transform(X_train)
plt.plot(X_train_PCA[0], X_train_PCA[1], 'o')
plt.xlabel('x1')
plt.ylabel('x2')
plt.title('Test')
# Out:
# Text(0.5, 1.0, 'Test')

# %%
error_values = {}
for i in range(2,15,1):
    pca_train = PCA(n_components=i)

    X_train_PCA = pca_train.fit_transform(X_train)
    X_test_PCA = pca_train.fit_transform(X_test)

    knn = KNeighborsClassifier(n_neighbors = best_n_neighbors).fit(X_train_PCA, y_train.astype('int'))

    err_train = np.mean(y_train.astype('int') != knn.predict(X_train_PCA))
    err_test = np.mean(y_test.astype('int') != knn.predict(X_test_PCA))
    error_values[i]=[err_train, err_test]

# %%
X_values = [item for item in error_values.keys()]
Y_values = [item[0] for item in error_values.values()]
Y_values_test = [item[1] for item in error_values.values()]
plt.plot(X_values, Y_values)
plt.plot(X_values, Y_values_test)
plt.xlabel('Number of PCA')
plt.ylabel('Error')
plt.title('Test')
# Out:
# Text(0.5, 1.0, 'Test')

# %%
#ошибка на обучающей выборке равна нулю
#минимальная ошибка на тестовой выборке достигается при числе компонент равном 2 и 3
print(error_values[2])
print(error_values[3])
# Out:
# [0.0, 0.5686274509803921]
# [0.0, 0.5686274509803921]
